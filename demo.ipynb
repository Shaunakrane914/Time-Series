# %%
text = "cat bat rat cat"
print(re.findall(cat,text))

# %%
text = "cat cot cut cpp"
print(re.findall(r"c.t",text))

# %%
text = "Hello World"
print(re.findall(r"world$",text))

# %%
text = "a ab abb abbb"
print(re.findall(r"ab",text))

# %%
text = "color colour"

print(re.findall(r"colou?r",text))

# %%
text = "apple ball cat dog"
print(re.findall(r"[abc]",text))

# %%
text = "Python123"
print(re.findall(r"[0^9]",text))

# %%
text - "I like Java"
print(re.sub("Java","Python",text))

# %%
#Split a sentence
text = "Apple,Banana,Mango"
print(re.split(",",text))

# %%
text = "Room 205,206"
print(re.findall(r"\d",text))

# %%
text = "Room 205 and 310"
print(re.findall(r"\d",text))

# %%
text = "A123B"
print(re.findall(r"\D",text))

# %%
text = "Python123"
print(re.findall("r[A-Za-z]",text ))

# %%
text = "Python NLP"
print(re.findall(r"[A-Z]",text))

# %%
text = "Python NLP"
print(re.findall(r"[a-z]",text))

# %%
text = "Python Programming Practice at Uai Campus"
print(re.findall(r"\bP\w",text))
