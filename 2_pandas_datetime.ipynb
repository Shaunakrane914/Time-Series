# %%
import pandas as pd
df = pd.read_csv("./data/upi_transactions.csv")
df.head()
# Out:
#   transaction id  transaction_date transaction type merchant_category  \
# 0  TXN0000000001  08-10-2024 15:17              P2P     Entertainment
# 1  TXN0000000002  11-04-2024 06:56              P2M           Grocery
# 2  TXN0000000003  02-04-2024 13:27              P2P           Grocery
# 3  TXN0000000004  07-01-2024 10:09              P2P              Fuel
# 4  TXN0000000005  23-01-2024 19:04              P2P          Shopping
#
#    amount (INR) transaction_status sender_age_group receiver_age_group  \
# 0           868            SUCCESS            26-35              18-25
# 1          1011            SUCCESS            26-35              26-35
# 2           477            SUCCESS            26-35              36-45
# 3          2784            SUCCESS            26-35              26-35
# 4           990            SUCCESS            26-35              18-25
#
#     sender_state sender_bank
# 0          Delhi        Axis
# 1  Uttar Pradesh       ICICI
# 2      Karnataka    Yes Bank
# 3          Delhi       ICICI
# 4          Delhi        Axis

# %%
df.shape
# Out:
# (250000, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   transaction id      250000 non-null  object
#  1   transaction_date    250000 non-null  object
#  2   transaction type    250000 non-null  object
#  3   merchant_category   250000 non-null  object
#  4   amount (INR)        250000 non-null  int64
#  5   transaction_status  250000 non-null  object
#  6   sender_age_group    250000 non-null  object
#  7   receiver_age_group  250000 non-null  object
#  8   sender_state        250000 non-null  object
#  9   sender_bank         250000 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 19.1+ MB

# %%
df["transaction_date"] = pd.to_datetime(

    df["transaction_date"],
    format = "%d-%m-%Y %H:%M"
)

# %%
df.info()

# %%
#Feature engineering
df["Year"] = df["transaction_date"].dt.year
df["Month"] = df["transaction_date"].dt.month
df["Day"] = df["transaction_date"].dt.day
df["Hour"] = df["transaction_date"].dt.hour
df["Minute"] = df["transaction_date"].dt.minute
df["Weekday"] = df["transaction_date"].dt.day_name()
df["Quarter"] = df["transaction_date"].dt.quarter

df.head()
# Out:
#   transaction id    transaction_date transaction type merchant_category  \
# 0  TXN0000000001 2024-10-08 15:17:00              P2P     Entertainment
# 1  TXN0000000002 2024-04-11 06:56:00              P2M           Grocery
# 2  TXN0000000003 2024-04-02 13:27:00              P2P           Grocery
# 3  TXN0000000004 2024-01-07 10:09:00              P2P              Fuel
# 4  TXN0000000005 2024-01-23 19:04:00              P2P          Shopping
#
#    amount (INR) transaction_status sender_age_group receiver_age_group  \
# 0           868            SUCCESS            26-35              18-25
# 1          1011            SUCCESS            26-35              26-35
# 2           477            SUCCESS            26-35              36-45
# 3          2784            SUCCESS            26-35              26-35
# 4           990            SUCCESS            26-35              18-25
#
#     sender_state sender_bank  Year  Month  Day  Hour  Minute   Weekday  \
# 0          Delhi        Axis  2024     10    8    15      17   Tuesday
# 1  Uttar Pradesh       ICICI  2024      4   11     6      56  Thursday
# 2      Karnataka    Yes Bank  2024      4    2    13      27   Tuesday
# 3          Delhi       ICICI  2024      1    7    10       9    Sunday
# 4          Delhi        Axis  2024      1   23    19       4   Tuesday
#
#    Quarter
# 0        4
# 1        2
# 2        2
# 3        1
# 4        1

# %%
df.iloc[0]
# Out:
# transaction id              TXN0000000001
# transaction_date      2024-10-08 15:17:00
# transaction type                      P2P
# merchant_category           Entertainment
# amount (INR)                          868
# transaction_status                SUCCESS
# sender_age_group                    26-35
# receiver_age_group                  18-25
# sender_state                        Delhi
# sender_bank                          Axis
# Year                                 2024
# Month                                  10
# Day                                     8
# Hour                                   15
# Minute                                 17
# Weekday                           Tuesday
# Quarter                                 4
# Name: 0, dtype: object

# %%
df = df.set_index("transaction_date")
df.head()
# Out:
#                     transaction id transaction type merchant_category  \
# transaction_date
# 2024-10-08 15:17:00  TXN0000000001              P2P     Entertainment
# 2024-04-11 06:56:00  TXN0000000002              P2M           Grocery
# 2024-04-02 13:27:00  TXN0000000003              P2P           Grocery
# 2024-01-07 10:09:00  TXN0000000004              P2P              Fuel
# 2024-01-23 19:04:00  TXN0000000005              P2P          Shopping
#
#                      amount (INR) transaction_status sender_age_group  \
# transaction_date
# 2024-10-08 15:17:00           868            SUCCESS            26-35
# 2024-04-11 06:56:00          1011            SUCCESS            26-35
# 2024-04-02 13:27:00           477            SUCCESS            26-35
# 2024-01-07 10:09:00          2784            SUCCESS            26-35
# 2024-01-23 19:04:00           990            SUCCESS            26-35
#
#                     receiver_age_group   sender_state sender_bank  Year  \
# transaction_date
# 2024-10-08 15:17:00              18-25          Delhi        Axis  2024
# 2024-04-11 06:56:00              26-35  Uttar Pradesh       ICICI  2024
# 2024-04-02 13:27:00              36-45      Karnataka    Yes Bank  2024
# 2024-01-07 10:09:00              26-35          Delhi       ICICI  2024
# 2024-01-23 19:04:00              18-25          Delhi        Axis  2024
#
#                      Month  Day  Hour  Minute   Weekday  Quarter
# transaction_date
# 2024-10-08 15:17:00     10    8    15      17   Tuesday        4
# 2024-04-11 06:56:00      4   11     6      56  Thursday        2
# 2024-04-02 13:27:00      4    2    13      27   Tuesday        2
# 2024-01-07 10:09:00      1    7    10       9    Sunday        1
# 2024-01-23 19:04:00      1   23    19       4   Tuesday        1

# %%
df.loc['2024-10-08']
# Out:
#                     transaction id transaction type merchant_category  \
# transaction_date
# 2024-10-08 15:17:00  TXN0000000001              P2P     Entertainment
# 2024-10-08 18:12:00  TXN0000000485              P2M          Shopping
# 2024-10-08 16:55:00  TXN0000001116              P2M              Food
