# %%
from datetime import datetime
from datetime import date
from datetime import time
from datetime import timedelta

# %%
from datetime import datetime 
now = datetime.now()
print(now)
# Out:
# 2026-07-27 11:37:56.252094

# %%
today = date.today()
print(today)


type(today)
# Out:
# 2026-07-27
# datetime.date

# %%
d = date(2026,8,15)
print(d)


print(d.year)
print(d.month)
print(d.day)
# Out:
# 2026-08-15
# 2026
# 8
# 15

# %%
from datetime import datetime 
now = datetime.now()
print(now)

print(now.year)
print(now.month)
print(now.day)
print(now.hour)
print(now.minute)
print(now.second)
# Out:
# 2026-07-27 11:37:56.283490
# 2026
# 7
# 27
# 11
# 37
# 56

# %%
print(now.strftime("%d - %m -%Y"))
print(now.strftime("%d%m%Y"))
print(now.strftime("%d %m %Y %H:%M:%S"))
print(now.strftime("%d  %B %Y"))
print(now.strftime("%A"))
# Out:
# 27 - 07 -2026
# 27072026
# 27 07 2026 11:37:56
# 27  July 2026
# Monday

# %%
dob = "15-08-2000"

date_obj = datetime.strptime(
    dob,
    "%d-%m-%Y"
)
print(date_obj)
# Out:
# 2000-08-15 00:00:00

# %%
from datetime import timedelta 
today = date.today()
after10days = today + timedelta(days=10)
print(after10days)
# Out:
# 2026-08-06

# %%
joining = date(2015,8,15)
today = date.today()
difference = today - joining
print(difference.days)
# Out:
# 3999

# %%
today = date.today()
difference = 3000
doj = today - timedelta(days=difference)
print(doj)
# Out:
# 2018-05-10

# %%
today.strftime("%A")
today.weekday()
# Out:
# 0

# %%
exam = date(2026,9,1)
today = date.today()
print(today<exam)
# Out:
# True

# %%
today = date.today()
future = today + timedelta(days=30)
print(future.strftime("%d-%B-%Y"))
# Out:
# 26-August-2026

# %%
from datetime import time

meeting = time(14,45,30)

print("Hour  :",meeting.hour)
print("Minute  :",meeting.minute)
print("second   :"meeting.second)
# Out:
#   Cell In[20], line 7
#     print("second   :"meeting.second)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
from datetime import time
office_start = time(9,0)
office_end = time(17,39)

print(office_start < office_end)
# Out:
# True

# %%
from datetime import datetime,time,date 


start = time(9,30)
end = time(17,45)

start_dt = datetime.combine(date.today(),start)
end_dt = datetime.combine(date.today(),end)

difference = end_dt - start_dt

print("Differnce: ",difference)
print("Hours:",difference.total_seconds)
# Out:
# Differnce:  8:15:00
# Hours: <built-in method total_seconds of datetime.timedelta object at 0x00000201ED51FB40>
